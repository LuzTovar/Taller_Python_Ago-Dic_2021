# %% [markdown]
# # Instituto Tecnológico Superior de San Luis Potosí, Capital.

# %% [markdown]
# # ![Logo ITSSLPC](Imagen/ITSSLPC.jpg \"ITSSLPC\")

# %% [markdown]
# ## Taller de Git, GitHub, MarkDown y Python¶
# ## ITSSLPC-ISC
# #### Actividades complementarias

# %%
print("Hola Mundo !!!")
# Out:
# Hola Mundo !!!

# %%
# hacer una suma
# los toma como string a y b y concatena
a = input("Dame el valor de a: ")
b = input("Dame el valor de b: ")
r = a + b
print("El resultado es: ", r)
# Out:
# Dame el valor de a:  23
# Dame el valor de b:  24
# El resultado es:  2324

# %%
print("hola " + "mundo ")
# Out:
# hola mundo

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El resultado es: ", r)
# Out:
# Dame el valor de a:  23
# Dame el valor de b:  54
# El resultado es:  77.0

# %% [markdown]
# #### **solicitar datos, hacer operaciones y entregamos resultados**

# %% [markdown]
# #### **formato de salida**

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El resultado es:  %.2f " %(r) )
# Out:
# Dame el valor de a:  15
# Dame el valor de b:  23
# El resultado es:  38.00

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El %.2f resultado es:  %.2f " %(r, r) )
# Out:
# Dame el valor de a:  52
# Dame el valor de b:  45
# El 97.00 resultado es:  97.00

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El %.1f resultado es:  %.3f " %(r, r) )
# Out:
# Dame el valor de a:  25
# Dame el valor de b:  63
# El 88.0 resultado es:  88.000

# %% [markdown]
# #### **Programa para convertir de kilómetros a millas**

# %% [markdown]
# #### **1 km = 0.621371 millas**

# %%
# solicitar los kilometros
k = float(input("Dame el número de kilómetros: "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("El valor en millas es:  %.3f " %(millas) )
# Out:
# Dame el número de kilómetros:  23.5
# El valor en millas es:  14.602

# %%
# solicitar los kilometros
k = float(input("Dame el número de kilómetros: "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
print("%.1f Kilometro(s) equivale a: %.2f " %(k, millas) )
# Out:
# Dame el número de kilómetros:  42.1
# 42.1 Kilometro(s) equivale a: 26.16

# %%
# solicitar los kilometros
k = float(input("Dame el número de kilometros: "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# Dame el número de kilometros:  75.3
# 75.3 Kilometro(s) equivale a: 46.79 millas

# %% [markdown]
# ### **Uso de condicionales IF**
# ##### **Pedimos el valor de kilómetros que se corrieron, los convertimos a millas**
# ##### **Si el valor de las millas es = 10 entonces imprimir "Meta no cumplida"**
# ##### **de otra forma impimir "Meta cumplida"**

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor

# le faltan los dos puntos en el else
if millas = 10:
    print("Meta no cumplida")
else
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
#   File "<ipython-input-15-cff136281f8c>", line 9
#     if millas = 10:
#               ^
# SyntaxError: invalid syntax

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )  

if millas == 10:
    print("Meta no cumplida")
else:
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# ¿Cuántos kilometros corriste ?  45.3
# 45.3 Kilometro(s) equivale a: 28.15 millas
# Meta cunplida

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )  

if millas == 10:
    print("Meta no cumplida")
else:
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# ¿Cuántos kilometros corriste ?  85.4
# 85.4 Kilometro(s) equivale a: 53.07 millas
# Meta cunplida

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )  

if millas == 10:
    print("Meta no cumplida")
else:
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# ¿Cuántos kilometros corriste ?  16
# 16.0 Kilometro(s) equivale a: 9.94 millas
# Meta cunplida
