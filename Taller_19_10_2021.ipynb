# %% [markdown]
# # Instituto Tecnológico Superior de San Luis Potosí, Capital.

# %% [markdown]
# # ![Logo ITSSLPC](Imagen/ITSSLPC.jpg \"ITSSLPC\")

# %% [markdown]
# ## Taller de Git, GitHub, MarkDown y Python¶
# ## ITSSLPC-ISC
# #### Actividades complementarias

# %%
a = 30

if a == 30:
    print("El valor es igual a 30")
# Out:
# El valor es igual a 30

# %%
a = 20

if a == 30:
    print("El valor es igual a 30")

# %%
a = 20

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")

# %%
a = 30

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
# Out:
# El valor es igual a 30

# %%
a = 31

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
# Out:
# El valor es mayor a 30

# %%
a = 30

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
else:
    print("El valor es menor a 30")
# Out:
# El valor es igual a 30

# %%
a = 31

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
else:
    print("El valor es menor a 30")
# Out:
# El valor es mayor a 30

# %%
a = 29

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
else:
    print("El valor es menor a 30")
# Out:
# El valor es menor a 30

# %% [markdown]
# **Adivina si el valor que nos proporciona el usuario, mayor, igual o menor a 50**

# %%
a = 49
if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# El valor es menor a 50

# %%
a = input("Ingrese el número que desea comparar")


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 48
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-c9d45c63545b> in <module>
#       4 if a == 50:
#       5     print("El valor es igual a 50")
# ----> 6 elif a > 50:
#       7     print("El valor es mayor a 50")
#       8 else:
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
a = int(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 50
# El valor es igual a 50

# %%
a = int(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 60
# El valor es mayor a 50

# %%
a = int(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 15
# El valor es menor a 50

# %%
a = int(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 10.10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-d1828c9eaad1> in <module>
# ----> 1 a = int(input("Ingrese el número que desea comparar"))
#       2
#       3
#       4 if a == 50:
#       5     print("El valor es igual a 50")
#
# ValueError: invalid literal for int() with base 10: '10.10'

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 10.10
# El valor es menor a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 80.80
# El valor es mayor a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 35.5
# El valor es menor a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 102.3
# El valor es mayor a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 1002.5
# El valor es mayor a 50
